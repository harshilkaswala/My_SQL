# %%
import pandas as pd

# %%
# !pip install nsepython
from nsepython import *

# %%
from sqlalchemy import create_engine

# %%
CE_values = []
PE_values = []

# %%
#fnolist
# Out:
# ['NIFTY',
#  'NIFTYIT',
#  'BANKNIFTY',
#  'BEL',
#  'TATACOMM',
#  'LALPATHLAB',
#  'GODREJCP',
#  'PEL',
#  'HONAUT',
#  'METROPOLIS',
#  'FSL',
#  'ABBOTINDIA',
#  'AXISBANK',
#  'AUBANK',
#  'HAL',
#  'ICICIGI',
#  'DABUR',
#  'NAUKRI',
#  'CANFINHOME',
#  'DIVISLAB',
#  'LUPIN',
#  'APLLTD',
#  'ASTRAL',
#  'JKCEMENT',
#  'BALRAMCHIN',
#  'ICICIPRULI',
#  'LICHSGFIN',
#  'HINDUNILVR',
#  'UBL',
#  'AMBUJACEM',
#  'SRTRANSFIN',
#  'ASHOKLEY',
#  'GSPL',
#  'ICICIBANK',
#  'INDUSTOWER',
#  'WHIRLPOOL',
#  'BSOFT',
#  'DRREDDY',
#  'TECHM',
#  'ATUL',
#  'PFIZER',
#  'M&M',
#  'DLF',
#  'OFSS',
#  'GLENMARK',
#  'M&MFIN',
#  'EXIDEIND',
#  'APOLLOHOSP',
#  'MANAPPURAM',
#  'HDFCLIFE',
#  'BIOCON',
#  'EICHERMOT',
#  'CIPLA',
#  'SBIN',
#  'SHREECEM',
#  'TORNTPHARM',
#  'IDEA',
#  'SIEMENS',
#  'IGL',
#  'BANDHANBNK',
#  'SBICARD',
#  'BRITANNIA',
#  'MFSL',
#  'HCLTECH',
#  'NTPC',
#  'HAVELLS',
#  'INDUSINDBK',
#  'BAJAJ-AUTO',
#  'RAMCOCEM',
#  'ALKEM',
#  'SRF',
#  'PFC',
# ...

# %%
##for i in range(180,len(fnolist)):
    ##payload=nse_optionchain_scrapper(fnolist[i])
    ##print(pcr(payload,1))

# %%
list1 = ['NIFTY',
 'NIFTYIT',
 'BANKNIFTY',
 'BEL',
 'TATACOMM',
 'LALPATHLAB',
 'GODREJCP',
 'PEL',
 'HONAUT',
 'METROPOLIS',
 'FSL',
 'ABBOTINDIA',
 'AXISBANK',
 'AUBANK',
 'HAL',
 'ICICIGI',
 'DABUR',
 'NAUKRI',
 'CANFINHOME',
 'DIVISLAB',
 'LUPIN',
 'APLLTD',
 'ASTRAL',
 'JKCEMENT',
 'BALRAMCHIN',
 'ICICIPRULI',
 'LICHSGFIN',
 'HINDUNILVR',
 'UBL',
 'AMBUJACEM',
 'SRTRANSFIN',
 'ASHOKLEY',
 'GSPL',
 'ICICIBANK',
 'INDUSTOWER',
 'WHIRLPOOL',
 'BSOFT',
 'DRREDDY',
 'TECHM',
 'ATUL',
 'PFIZER',
 'M&M',
 'DLF',
 'OFSS',
 'GLENMARK',
 'M&MFIN',
 'EXIDEIND',
 'APOLLOHOSP',
 'MANAPPURAM',
 'HDFCLIFE',
 'BIOCON',
 'EICHERMOT',
 'CIPLA',
 'SBIN',
 'SHREECEM',
 'TORNTPHARM',
 'IDEA',
 'SIEMENS',
 'IGL',
 'BANDHANBNK',
 'SBICARD',
 'BRITANNIA',
 'MFSL',
 'HCLTECH',
 'NTPC',
 'HAVELLS',
 'INDUSINDBK',
 'BAJAJ-AUTO',
 'RAMCOCEM',
 'ALKEM',
 'SRF',
 'PFC',
 'INDIGO',
 'BHARATFORG',
 'PETRONET',
 'SBILIFE',
 'SUNPHARMA',
 'HEROMOTOCO',
 'ZYDUSLIFE',
 'SUNTV',
 'STAR',
 'ASIANPAINT',
 'DEEPAKNTR',
 'INDIACEM',
 'APOLLOTYRE',
 'BOSCHLTD',
 'UPL',
 'AMARAJABAT',
 'DALBHARAT',
 'MGL',
 'JUBLFOOD',
 'SYNGENE',
 'BHEL',
 'ULTRACEMCO',
 'ACC',
 'MUTHOOTFIN',
 'CUMMINSIND',
 'NESTLEIND',
 'PNB',
 'BERGEPAINT',
 'IRCTC',
 'INDHOTEL',
 'BANKBARODA',
 'PAGEIND',
 'ABCAPITAL',
 'RECLTD',
 'COLPAL',
 'TATACONSUM',
 'AUROPHARMA',
 'ABB',
 'CANBK',
 'MRF',
 'KOTAKBANK',
 'PVR',
 'NMDC',
 'MCX',
 'INFY',
 'BAJFINANCE',
 'GODREJPROP',
 'TORNTPOWER',
 'FEDERALBNK',
 'MPHASIS',
 'GAIL',
 'NBCC',
 'OBEROIRLTY',
 'BAJAJFINSV',
 'HINDPETRO',
 'AARTIIND',
 'CUB',
 'COALINDIA',
 'GRASIM',
 'HINDALCO',
 'TVSMOTOR',
 'BPCL',
 'IBULHSGFIN',
 'ITC',
 'JSWSTEEL',
 'LAURUSLABS',
 'GMRINFRA',
 'TATASTEEL',
 'MARUTI',
 'PIIND',
 'SAIL',
 'TATAMOTORS',
 'BALKRISIND',
 'VOLTAS',
 'ABFRL',
 'MOTHERSUMI',
 'RAIN',
 'GUJGASLTD',
 'LT',
 'RBLBANK',
 'MINDTREE',
 'HDFCAMC',
 'GRANULES',
 'PIDILITIND',
 'POLYCAB',
 'VEDL',
 'BHARTIARTL',
 'MARICO',
 'IPCALAB',
 'COROMANDEL',
 'CROMPTON',
 'LTI',
 'TRENT',
 'NAVINFLUOR',
 'COFORGE',
 'RELIANCE',
 'INTELLECT',
 'IOC',
 'POWERGRID',
 'JINDALSTEL',
 'WIPRO',
 'HDFCBANK',
 'TCS',
 'CHAMBLFERT',
 'ZEEL',
 'DELTACORP',
 'TATACHEM',
 'CHOLAFIN',
 'L&TFH',
 'ONGC',
 'HINDCOPPER',
 'IDFCFIRSTB',
 'BATAINDIA',
 'MCDOWELL-N',
 'ADANIENT',
 'HDFC',
 'IEX',
 'DIXON',
 'INDIAMART',
 'GNFC',
 'LTTS',
 'PERSISTENT',
 'TITAN',
 'CONCOR',
 'ADANIPORTS',
 'NAM-INDIA',
 'NATIONALUM',
 'TATAPOWER',
 'IDFC',
 'ESCORTS']

# %%
for i in range(len(list1)):
    nse = nse_optionchain_scrapper(list1[i])
    CE_OI = nse['filtered']['CE']['totOI']
    PE_OI = nse['filtered']['PE']['totOI']
    CE_values.append(CE_OI)
    PE_values.append(PE_OI)
    
    
    #pcr_values.append(values)

# %%
#fnolist.index('HINDUNILVR')
# Out:
# 22

# %%
#del list1[1]

# %%
df = pd.DataFrame(
{"STOCK" : list1,
"CE_OI" : CE_values,
"PE_OI":PE_values}
)

# %%
df
# Out:
#           STOCK    CE_OI    PE_OI
# 0         NIFTY  1405260   940684
# 1     BANKNIFTY  1185452  1029322
# 2           BEL     6576     3349
# 3      TATACOMM     3710      912
# 4    LALPATHLAB     1567      363
# ..          ...      ...      ...
# 196   NAM-INDIA      688      155
# 197  NATIONALUM     3403     1680
# 198   TATAPOWER    14583     9518
# 199        IDFC     3964     2081
# 200     ESCORTS     5797     1397
#
# [201 rows x 3 columns]

# %%
engine = create_engine('mysql+mysqldb://admin:sql_2021@project-db.c8h2tkspsqfa.us-east-1.rds.amazonaws.com/Stock_Prices')

# %%
df.to_sql("CALL_PUT_OI", engine, if_exists ='replace', index = False)
