# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (0.3.9)
# Requirement already satisfied: sqlparse in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython-sql) (0.4.2)
# Requirement already satisfied: ipython>=1.0 in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython-sql) (7.29.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: six in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: prettytable in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython-sql) (3.0.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython-sql) (1.4.27)
# Requirement already satisfied: setuptools>=18.5 in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (58.0.4)
# Requirement already satisfied: matplotlib-inline in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.18.1)
# Requirement already satisfied: backcall in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: pygments in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (2.10.0)
# Requirement already satisfied: appnope in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (3.0.20)
# Requirement already satisfied: pexpect>4.3 in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: pickleshare in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: decorator in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.1.0)
# Requirement already satisfied: traitlets>=4.2 in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from pexpect>4.3->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: greenlet!=0.4.17 in ./opt/anaconda3/envs/Spring_2021/lib/python3.8/site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.1.1)

# %%
# %load_ext sql

# %%
mysql://USERNAME:PASSWORD@HOST/DATABASE
# Out:
# 'Connected: admin@Stock_Prices'

# %% [markdown]
# ### This query describes the number of stocks which didnt have a single trade on the particular day the data was collected

# %%
# %%sql
# WITH zero_trades AS (
# SELECT COUNT(Stock_Ticker) AS total_stocks,
# 	COUNT(CASE WHEN (Call_price = 0 OR put_price = 0)THEN 1 ELSE NULL END) AS zero_trades_stock
# FROM ATM_prices ap
# )
# SELECT zero_trades_stock,
# 	total_stocks,
# 	ROUND((zero_trades_stock/total_stocks)*100,2) AS Percentage
# FROM zero_trades ;
# Out:
#  * mysql://admin:***@project-db.c8h2tkspsqfa.us-east-1.rds.amazonaws.com/Stock_Prices
# 1 rows affected.
# [(38, 198, Decimal('19.19'))]

# %% [markdown]
# #### As it can be seen from the query results that 38 stocks or 19 percent of the stocks didnt register a trade in either call or put

# %% [markdown]
# ### In this query we will looking at put to call ratios of stocks, they tend to follow a normal distribution so we will look at stock which have a PCR value out of the 2 standard deviation away from mean.

# %%
# %%sql
# SELECT
# 	STD(PE_OI/CE_OI) AS STD,
# 	AVG(PE_OI/CE_OI) AS MEAN,
# 	(AVG(PE_OI/CE_OI)-(3*STD(PE_OI/CE_OI))) AS Low_Range,
# 	(AVG(PE_OI/CE_OI)+(3*STD(PE_OI/CE_OI))) AS High_Range
# FROM CALL_PUT_OI cpo;
#
# SELECT STOCK,
# 	PE_OI/CE_OI,
# 	COUNT(Stock) OVER() AS Count
# FROM CALL_PUT_OI cpo
# WHERE (PE_OI/CE_OI) > 0.924 OR (PE_OI/CE_OI) < 0.00065
# Out:
#  * mysql://admin:***@project-db.c8h2tkspsqfa.us-east-1.rds.amazonaws.com/Stock_Prices
# 1 rows affected.
# 1 rows affected.
# [('POWERGRID', Decimal('0.9832'), 1)]

# %% [markdown]
# #### Powergrid is the only stock which PCR lies out of the 2 STD range, hence we should analyze if there is any trading opportunities.

# %% [markdown]
# ### In this query we will segregate the data into 4 different quartiles accoridng to their premium percentage and then find the average premium percentage for each quartile

# %%
# %%sql
# WITH premium_of_options AS (
# SELECT ns.Stock_Ticker,
# 	sp.Prices,
# 	Call_price,
# 	put_price,
# 	Call_price + put_price AS Straddle_Price,
# 	ROUND(((Call_price + put_price)/Prices)*100,2) AS Premium,
# 	CASE WHEN sp.Prices >= 3000 THEN "High Value Stock" ELSE "Low Value Stock" END AS Stock_Type
# FROM Non_Zero_Stock ns
# JOIN Stock_Prices sp
# 	ON ns.Stock_Ticker = sp.Stock_Ticker
# ORDER BY ROUND(((Call_price + put_price)/Prices)*100,2) DESC
# ),
# Ranks AS (
# SELECT Stock_Ticker,
# 	Prices,
# 	Premium,
# 	ROUND(PERCENT_RANK() OVER (ORDER BY Premium),2) AS percentile
# FROM premium_of_options
# )
# SELECT
# 	ROUND(AVG(CASE WHEN percentile > 0.75 THEN Premium ELSE NULL END),2) AS Upper_Quartile_Premium,
# 	ROUND(AVG(CASE WHEN percentile > 0.25 AND percentile < 0.75 THEN Premium ELSE NULL END),2) Middle_Quartile_Premium,
# 	ROUND(AVG(CASE WHEN percentile < 0.25 THEN Premium ELSE NULL END),2) AS Lower_Quartile_Premium
# FROM Ranks ;
# Out:
#  * mysql://admin:***@project-db.c8h2tkspsqfa.us-east-1.rds.amazonaws.com/Stock_Prices
# 1 rows affected.
# [(10.31, 8.18, 5.89)]

# %% [markdown]
# #### Each of the above values represents a premium value in their quartile

# %% [markdown]
# ### In this query we will segregate the data into 4 different quartiles accoridng to their premium percentage and then find the average stock price for each quartile, usually high premium stocks tend to have a lower price.

# %%
# %%sql
# WITH premium_of_options AS (
# SELECT ns.Stock_Ticker,
# 	sp.Prices,
# 	Call_price,
# 	put_price,
# 	Call_price + put_price AS Straddle_Price,
# 	ROUND(((Call_price + put_price)/Prices)*100,2) AS Premium,
# 	CASE WHEN sp.Prices >= 3000 THEN "High Value Stock" ELSE "Low Value Stock" END AS Stock_Type
# FROM Non_Zero_Stock ns
# JOIN Stock_Prices sp
# 	ON ns.Stock_Ticker = sp.Stock_Ticker
# ORDER BY ROUND(((Call_price + put_price)/Prices)*100,2) DESC
# ),
# Ranks AS (
# SELECT Stock_Ticker,
# 	Prices,
# 	Premium,
# 	ROUND(PERCENT_RANK() OVER (ORDER BY Premium),2) AS percentile
# FROM premium_of_options
# )
# SELECT
# 	ROUND(AVG(CASE WHEN percentile > 0.75 THEN Prices  ELSE NULL END),2) AS Upper_Quartile_Premium,
# 	ROUND(AVG(CASE WHEN percentile > 0.25 AND percentile < 0.75 THEN Prices  ELSE NULL END),2) Middle_Quartile_Premium,
# 	ROUND(AVG(CASE WHEN percentile < 0.25 THEN Prices  ELSE NULL END),2) AS Lower_Quartile_Premium
# FROM Ranks ;
# Out:
#  * mysql://admin:***@project-db.c8h2tkspsqfa.us-east-1.rds.amazonaws.com/Stock_Prices
# 1 rows affected.
# [(986.77, 2143.67, 3599.07)]

# %% [markdown]
# #### It can be confirmed from the data that the higher quartile premium had the lowest prices and lowest quartile premium had the highest prices

# %% [markdown]
# ### In this query we will be looking at the PCR ratio according to stock prices, where any stock prcied at more than 3000 is high value and rest are low value

# %%
# %%sql
# WITH Value_1 AS (
# SELECT ns.Stock_Ticker,
# 	sp.Prices,
# 	CASE WHEN sp.Prices >= 3000 THEN "High Value Stock" ELSE "Low Value Stock" END AS Stock_Type
# FROM Non_Zero_Stock ns
# JOIN Stock_Prices sp
# 	ON ns.Stock_Ticker = sp.Stock_Ticker
# ORDER BY ROUND(((Call_price + put_price)/Prices)*100,2) DESC
# )
# SELECT Stock_Type,
# 	AVG(PE_OI/CE_OI) AS Average_OI
# FROM CALL_PUT_OI cpo
# JOIN Value_1
# 	ON cpo.STOCK = Value_1.Stock_Ticker
# GROUP BY Stock_Type ;
# Out:
#  * mysql://admin:***@project-db.c8h2tkspsqfa.us-east-1.rds.amazonaws.com/Stock_Prices
# 2 rows affected.
# [('High Value Stock', Decimal('0.44778000')),
#  ('Low Value Stock', Decimal('0.48306889'))]

# %% [markdown]
# #### Accordding to our results it can be seen that there is no significant different between the two stock classes

# %% [markdown]
# ## business question 1 - Which stocks have the highest premium and hence are most profitbale to short

# %% [markdown]
# #### Filter out all stocks that didnt have a trade that day
# SQL Features Used Views

# %%
# %%sql
# #Step 1: Filer all the stocks which didnt have any trades that day, that means any call or put price that is zero.
# #CREATE VIEW Non_Zero_Stock AS
# #SELECT *
# #FROM ATM_prices ap
# #WHERE Call_price <> 0 AND put_price <>0;
# Out:
#  * mysql://admin:***@project-db.c8h2tkspsqfa.us-east-1.rds.amazonaws.com/Stock_Prices
# 0 rows affected.
# []

# %% [markdown]
# #### Step 2: Find highest option premiums
# #### SQL features used:
# #### JOIN,
# #### CASE

# %%
# %%sql
# SELECT ns.Stock_Ticker,
# 	sp.Prices,
# 	Call_price,
# 	put_price,
# 	Call_price + put_price AS Straddle_Price,
# 	ROUND(((Call_price + put_price)/Prices)*100,2) AS Premium,
# 	CASE WHEN sp.Prices >= 3000 THEN "High Value Stock" ELSE "Low Value Stock" END AS Stock_Type
# FROM Non_Zero_Stock ns
# JOIN Stock_Prices sp
# 	ON ns.Stock_Ticker = sp.Stock_Ticker
# ORDER BY ROUND(((Call_price + put_price)/Prices)*100,2) DESC;
# Out:
#  * mysql://admin:***@project-db.c8h2tkspsqfa.us-east-1.rds.amazonaws.com/Stock_Prices
# 160 rows affected.
# [('IDEA', 10.1, 0.85, 0.65, 1.5, 14.85, 'Low Value Stock'),
#  ('IBULHSGFIN', 167.35, 12.85, 9.2, 22.049999999999997, 13.18, 'Low Value Stock'),
#  ('MOTHERSUMI', 140.25, 8.7, 7.85, 16.549999999999997, 11.8, 'Low Value Stock'),
#  ('BALRAMCHIN', 483.45, 26.7, 28.3, 55.0, 11.38, 'Low Value Stock'),
#  ('DELTACORP', 333.7, 18.9, 18.8, 37.7, 11.3, 'Low Value Stock'),
#  ('STAR', 352.5, 22.0, 17.7, 39.7, 11.26, 'Low Value Stock'),
#  ('ZEEL', 299.45, 17.6, 15.9, 33.5, 11.19, 'Low Value Stock'),
#  ('FSL', 128.8, 6.75, 7.4, 14.15, 10.99, 'Low Value Stock'),
#  ('INDIAMART', 4473.95, 220.0, 261.0, 481.0, 10.75, 'High Value Stock'),
#  ('ESCORTS', 1700.0, 18.0, 162.0, 180.0, 10.59, 'Low Value Stock'),
#  ('RAIN', 202.05, 12.1, 9.2, 21.299999999999997, 10.54, 'Low Value Stock'),
#  ('BSOFT', 468.4, 24.1, 24.9, 49.0, 10.46, 'Low Value Stock'),
#  ('CHAMBLFERT', 429.35, 24.1, 20.25, 44.35, 10.33, 'Low Value Stock'),
#  ('METROPOLIS', 2095.0, 108.0, 107.3, 215.3, 10.28, 'Low Value Stock'),
#  ('GNFC', 862.15, 46.6, 42.0, 88.6, 10.28, 'Low Value Stock'),
#  ('INTELLECT', 912.0, 45.1, 48.65, 93.75, 10.28, 'Low Value Stock'),
#  ('JUBLFOOD', 2726.0, 137.55, 142.3, 279.85, 10.27, 'Low Value Stock'),
#  ('BHEL', 53.8, 2.8, 2.65, 5.449999999999999, 10.13, 'Low Value Stock'),
#  ('GSPL', 260.0, 12.6, 13.6, 26.2, 10.08, 'Low Value Stock'),
#  ('INDUSTOWER', 221.45, 12.45, 9.65, 22.1, 9.98, 'Low Value Stock'),
#  ('GUJGASLTD', 495.25, 23.9, 25.5, 49.4, 9.97, 'Low Value Stock'),
#  ('NBCC', 38.2, 2.1, 1.7, 3.8, 9.95, 'Low Value Stock'),
#  ('JINDALSTEL', 530.35, 28.3, 24.4, 52.7, 9.94, 'Low Value Stock'),
#  ('RBLBANK', 136.95, 6.8, 6.7, 13.5, 9.86, 'Low Value Stock'),
#  ('IDFCFIRSTB', 41.75, 1.95, 2.1, 4.05, 9.7, 'Low Value Stock'),
#  ('MANAPPURAM', 120.7, 6.6, 5.1, 11.7, 9.69, 'Low Value Stock'),
#  ('NATIONALUM', 122.15, 6.0, 5.75, 11.75, 9.62, 'Low Value Stock'),
#  ('OBEROIRLTY', 982.5, 51.3, 43.0, 94.3, 9.6, 'Low Value Stock'),
#  ('ABFRL', 300.05, 14.35, 14.45, 28.799999999999997, 9.6, 'Low Value Stock'),
#  ('MINDTREE', 4243.3, 233.25, 170.15, 403.4, 9.51, 'High Value Stock'),
#  ('APOLLOHOSP', 4501.5, 221.5, 206.0, 427.5, 9.5, 'High Value Stock'),
#  ('BANDHANBNK', 320.1, 15.85, 14.45, 30.299999999999997, 9.47, 'Low Value Stock'),
#  ('INDIGO', 2000.15, 100.95, 88.0, 188.95, 9.45, 'Low Value Stock'),
#  ('SRTRANSFIN', 1189.75, 62.5, 49.85, 112.35, 9.44, 'Low Value Stock'),
#  ('DEEPAKNTR', 2300.0, 114.05, 103.0, 217.05, 9.44, 'Low Value Stock'),
#  ('LALPATHLAB', 2587.0, 119.3, 125.0, 244.3, 9.44, 'Low Value Stock'),
#  ('ASHOKLEY', 119.35, 5.4, 5.75, 11.15, 9.34, 'Low Value Stock'),
#  ('TATAMOTORS', 440.9, 22.35, 18.8, 41.150000000000006, 9.33, 'Low Value Stock'),
#  ('GODREJPROP', 1694.25, 81.4, 76.2, 157.60000000000002, 9.3, 'Low Value Stock'),
#  ('GMRINFRA', 38.75, 1.8, 1.8, 3.6, 9.29, 'Low Value Stock'),
#  ('DIXON', 4365.15, 185.0, 219.95, 404.95, 9.28, 'High Value Stock'),
#  ('PVR', 1910.0, 100.0, 77.25, 177.25, 9.28, 'Low Value Stock'),
#  ('IEX', 230.85, 11.75, 9.5, 21.25, 9.21, 'Low Value Stock'),
#  ('LTI', 6175.0, 267.0, 300.0, 567.0, 9.18, 'High Value Stock'),
#  ('COFORGE', 4420.0, 226.95, 179.0, 405.95, 9.18, 'High Value Stock'),
#  ('NAUKRI', 4605.05, 220.0, 202.0, 422.0, 9.16, 'High Value Stock'),
#  ('INDHOTEL', 241.3, 12.6, 9.5, 22.1, 9.16, 'Low Value Stock'),
#  ('IDFC', 63.65, 2.95, 2.85, 5.800000000000001, 9.11, 'Low Value Stock'),
#  ('HAL', 1521.3, 74.5, 64.0, 138.5, 9.1, 'Low Value Stock'),
#  ('DLF', 385.0, 18.7, 16.3, 35.0, 9.09, 'Low Value Stock'),
#  ('LTTS', 5118.95, 258.5, 205.8, 464.3, 9.07, 'High Value Stock'),
#  ('BANKBARODA', 116.0, 5.5, 5.0, 10.5, 9.05, 'Low Value Stock'),
#  ('HINDALCO', 571.0, 27.15, 24.45, 51.599999999999994, 9.04, 'Low Value Stock'),
#  ('IRCTC', 797.75, 34.8, 36.8, 71.6, 8.98, 'Low Value Stock'),
#  ('TATASTEEL', 1317.15, 59.95, 58.3, 118.25, 8.98, 'Low Value Stock'),
#  ('ADANIENT', 2038.0, 97.5, 84.35, 181.85, 8.92, 'Low Value Stock'),
#  ('WHIRLPOOL', 1604.9, 82.9, 60.15, 143.05, 8.91, 'Low Value Stock'),
#  ('TATACOMM', 1237.0, 57.0, 52.9, 109.9, 8.88, 'Low Value Stock'),
#  ('PERSISTENT', 4728.0, 220.0, 200.0, 420.0, 8.88, 'High Value Stock'),
#  ('CONCOR', 681.0, 32.2, 28.05, 60.25, 8.85, 'Low Value Stock'),
#  ('ADANIPORTS', 783.5, 38.5, 30.6, 69.1, 8.82, 'Low Value Stock'),
#  ('APOLLOTYRE', 195.7, 9.4, 7.85, 17.25, 8.81, 'Low Value Stock'),
#  ('AUBANK', 1280.6, 60.0, 52.35, 112.35, 8.77, 'Low Value Stock'),
#  ('SRF', 2625.8, 122.0, 107.55, 229.55, 8.74, 'Low Value Stock'),
#  ('VEDL', 405.9, 19.45, 16.0, 35.45, 8.73, 'Low Value Stock'),
#  ('SYNGENE', 598.05, 25.5, 26.4, 51.9, 8.68, 'Low Value Stock'),
#  ('TATAPOWER', 245.8, 11.75, 9.45, 21.2, 8.62, 'Low Value Stock'),
#  ('LICHSGFIN', 372.35, 18.35, 13.6, 31.950000000000003, 8.58, 'Low Value Stock'),
#  ('JSWSTEEL', 732.45, 33.45, 28.85, 62.300000000000004, 8.51, 'Low Value Stock'),
#  ('CUMMINSIND', 1132.1, 48.4, 47.0, 95.4, 8.43, 'Low Value Stock'),
#  ('NAM-INDIA', 338.4, 14.5, 13.95, 28.45, 8.41, 'Low Value Stock'),
#  ('BALKRISIND', 2108.0, 96.0, 79.55, 175.55, 8.33, 'Low Value Stock'),
#  ('AUROPHARMA', 682.5, 31.2, 25.55, 56.75, 8.32, 'Low Value Stock'),
#  ('TORNTPOWER', 500.25, 23.5, 18.0, 41.5, 8.3, 'Low Value Stock'),
#  ('TRENT', 1268.0, 60.85, 43.35, 104.2, 8.22, 'Low Value Stock'),
#  ('HINDPETRO', 276.2, 12.8, 9.85, 22.65, 8.2, 'Low Value Stock'),
#  ('AMBUJACEM', 305.0, 13.0, 12.0, 25.0, 8.2, 'Low Value Stock'),
#  ('PEL', 2232.7, 87.5, 95.3, 182.8, 8.19, 'Low Value Stock'),
#  ('BEL', 214.8, 9.5, 8.1, 17.6, 8.19, 'Low Value Stock'),
#  ('GLENMARK', 452.05, 20.6, 16.25, 36.85, 8.15, 'Low Value Stock'),
#  ('LAURUSLABS', 597.55, 24.8, 23.9, 48.7, 8.15, 'Low Value Stock'),
#  ('MGL', 795.0, 36.6, 27.85, 64.45, 8.11, 'Low Value Stock'),
#  ('COALINDIA', 186.0, 8.55, 6.5, 15.05, 8.09, 'Low Value Stock'),
#  ('CHOLAFIN', 706.9, 29.65, 27.25, 56.9, 8.05, 'Low Value Stock'),
#  ('TATACHEM', 985.85, 41.75, 37.5, 79.25, 8.04, 'Low Value Stock'),
#  ('HEROMOTOCO', 2246.0, 98.3, 82.0, 180.3, 8.03, 'Low Value Stock'),
#  ('AARTIIND', 957.15, 36.9, 39.85, 76.75, 8.02, 'Low Value Stock'),
#  ('CANBK', 239.45, 9.8, 9.35, 19.15, 8.0, 'Low Value Stock'),
#  ('GODREJCP', 754.25, 32.8, 27.5, 60.3, 7.99, 'Low Value Stock'),
#  ('BHARATFORG', 704.0, 31.75, 24.35, 56.1, 7.97, 'Low Value Stock'),
#  ('UBL', 1501.0, 62.1, 56.2, 118.30000000000001, 7.88, 'Low Value Stock'),
#  ('FEDERALBNK', 101.3, 4.4, 3.55, 7.95, 7.85, 'Low Value Stock'),
#  ('GRANULES', 313.0, 12.3, 11.95, 24.25, 7.75, 'Low Value Stock'),
#  ('MCX', 1441.0, 61.5, 50.0, 111.5, 7.74, 'Low Value Stock'),
#  ('PNB', 36.35, 1.7, 1.1, 2.8, 7.7, 'Low Value Stock'),
#  ('IGL', 380.5, 15.55, 13.75, 29.3, 7.7, 'Low Value Stock'),
#  ('BAJAJFINSV', 17150.0, 660.0, 655.0, 1315.0, 7.67, 'High Value Stock'),
#  ('VOLTAS', 1260.0, 49.3, 46.15, 95.44999999999999, 7.58, 'Low Value Stock'),
#  ('BERGEPAINT', 710.3, 24.5, 29.2, 53.7, 7.56, 'Low Value Stock'),
#  ('NAVINFLUOR', 4050.0, 155.0, 150.85, 305.85, 7.55, 'High Value Stock'),
#  ('HAVELLS', 1172.5, 42.3, 46.05, 88.35, 7.54, 'Low Value Stock'),
#  ('SUNTV', 498.0, 20.45, 17.05, 37.5, 7.53, 'Low Value Stock'),
#  ('NMDC', 166.3, 6.15, 6.35, 12.5, 7.52, 'Low Value Stock'),
#  ('ACC', 2150.0, 64.5, 97.15, 161.65, 7.52, 'Low Value Stock'),
#  ('TVSMOTOR', 627.7, 24.7, 22.25, 46.95, 7.48, 'Low Value Stock'),
#  ('TATACONSUM', 788.25, 30.3, 28.4, 58.7, 7.45, 'Low Value Stock'),
#  ('CUB', 133.9, 4.85, 5.0, 9.85, 7.36, 'Low Value Stock'),
#  ('MUTHOOTFIN', 1353.0, 46.15, 53.05, 99.19999999999999, 7.33, 'Low Value Stock'),
#  ('INDUSINDBK', 968.0, 36.4, 34.5, 70.9, 7.32, 'Low Value Stock'),
#  ('ONGC', 167.7, 6.5, 5.75, 12.25, 7.3, 'Low Value Stock'),
#  ('BATAINDIA', 1995.0, 77.0, 67.0, 144.0, 7.22, 'Low Value Stock'),
#  ('BIOCON', 342.45, 13.9, 10.7, 24.6, 7.18, 'Low Value Stock'),
#  ('OFSS', 3590.0, 130.5, 125.7, 256.2, 7.14, 'High Value Stock'),
#  ('MARUTI', 7670.0, 269.05, 276.45, 545.5, 7.11, 'High Value Stock'),
#  ('BAJFINANCE', 7429.0, 299.0, 223.55, 522.55, 7.03, 'High Value Stock'),
#  ('SBICARD', 870.0, 32.0, 29.1, 61.1, 7.02, 'Low Value Stock'),
#  ('PAGEIND', 43148.95, 1430.0, 1600.45, 3030.45, 7.02, 'High Value Stock'),
#  ('COROMANDEL', 797.0, 27.6, 27.75, 55.35, 6.94, 'Low Value Stock'),
#  ('TECHM', 1489.0, 60.0, 43.0, 103.0, 6.92, 'Low Value Stock'),
#  ('ALKEM', 3498.0, 113.3, 127.4, 240.7, 6.88, 'High Value Stock'),
#  ('SBILIFE', 1116.7, 37.2, 38.3, 75.5, 6.76, 'Low Value Stock'),
#  ('LUPIN', 763.45, 30.0, 21.4, 51.4, 6.73, 'Low Value Stock'),
#  ('BOSCHLTD', 14575.9, 550.0, 430.0, 980.0, 6.72, 'High Value Stock'),
#  ('DIVISLAB', 4375.0, 169.2, 124.55, 293.75, 6.71, 'High Value Stock'),
#  ('GRASIM', 1665.2, 65.3, 46.25, 111.55, 6.7, 'Low Value Stock'),
#  ('AXISBANK', 773.5, 28.5, 22.95, 51.45, 6.65, 'Low Value Stock'),
#  ('TITAN', 2526.0, 92.2, 74.2, 166.4, 6.59, 'Low Value Stock'),
#  ('UPL', 781.55, 27.45, 23.75, 51.2, 6.55, 'Low Value Stock'),
#  ('MCDOWELL-N', 900.3, 32.7, 26.1, 58.800000000000004, 6.53, 'Low Value Stock'),
#  ('HDFCLIFE', 551.1, 19.0, 16.65, 35.65, 6.47, 'Low Value Stock'),
#  ('SBIN', 508.0, 16.85, 15.9, 32.75, 6.45, 'Low Value Stock'),
#  ('DRREDDY', 4278.0, 134.95, 139.5, 274.45, 6.42, 'High Value Stock'),
#  ('CIPLA', 1018.65, 33.3, 31.95, 65.25, 6.41, 'Low Value Stock'),
#  ('IOC', 121.95, 4.15, 3.6, 7.75, 6.36, 'Low Value Stock'),
#  ('ULTRACEMCO', 6656.05, 204.0, 219.0, 423.0, 6.36, 'High Value Stock'),
#  ('WIPRO', 602.75, 16.55, 21.5, 38.05, 6.31, 'Low Value Stock'),
#  ('ASIANPAINT', 3112.2, 102.0, 93.35, 195.35, 6.28, 'High Value Stock'),
#  ('RECLTD', 127.1, 4.0, 3.8, 7.8, 6.14, 'Low Value Stock'),
#  ('INFY', 1906.8, 62.5, 53.0, 115.5, 6.06, 'Low Value Stock'),
#  ('KOTAKBANK', 1780.0, 58.0, 49.75, 107.75, 6.05, 'Low Value Stock'),
#  ('ICICIBANK', 736.0, 21.05, 23.45, 44.5, 6.05, 'Low Value Stock'),
#  ('BPCL', 374.65, 11.7, 10.85, 22.549999999999997, 6.02, 'Low Value Stock'),
#  ('ABBOTINDIA', 17500.0, 556.35, 490.0, 1046.35, 5.98, 'High Value Stock'),
#  ('HCLTECH', 1173.2, 36.35, 33.2, 69.55000000000001, 5.93, 'Low Value Stock'),
#  ('MARICO', 519.0, 14.8, 15.4, 30.200000000000003, 5.82, 'Low Value Stock'),
#  ('ITC', 255.05, 8.0, 6.5, 14.5, 5.69, 'Low Value Stock'),
#  ('PFC', 116.4, 3.75, 2.8, 6.55, 5.63, 'Low Value Stock'),
#  ('RELIANCE', 2661.0, 79.0, 69.0, 148.0, 5.56, 'Low Value Stock'),
#  ('BHARTIARTL', 758.35, 19.7, 21.15, 40.849999999999994, 5.39, 'Low Value Stock'),
#  ('NTPC', 142.8, 4.0, 3.65, 7.65, 5.36, 'Low Value Stock'),
#  ('TCS', 3759.0, 104.8, 94.4, 199.2, 5.3, 'High Value Stock'),
#  ('SUNPHARMA', 911.8, 26.85, 21.35, 48.2, 5.29, 'Low Value Stock'),
#  ('POWERGRID', 225.45, 6.3, 5.5, 11.8, 5.23, 'Low Value Stock'),
#  ('COLPAL', 1549.85, 46.0, 35.0, 81.0, 5.23, 'Low Value Stock'),
#  ('HDFCBANK', 1507.5, 34.4, 42.3, 76.69999999999999, 5.09, 'Low Value Stock'),
#  ('BANKNIFTY', 37148.5, 1028.0, 850.1, 1878.1, 5.06, 'High Value Stock'),
#  ('HDFC', 2462.25, 68.0, 56.35, 124.35, 5.05, 'Low Value Stock'),
#  ('LT', 1786.2, 53.7, 36.3, 90.0, 5.04, 'Low Value Stock'),
#  ('HINDUNILVR', 2082.6, 56.75, 45.25, 102.0, 4.9, 'Low Value Stock'),
#  ('NIFTY', 17670.45, 375.85, 285.0, 660.85, 3.74, 'High Value Stock')]

# %% [markdown]
# #### The results have sorted the highest premium relative to their price first, for instance the first value is TATA, implying the options of TATA are most profitable to short

# %% [markdown]
# ## Additonal Question 1 : --  After you have identified the most profitbale premiums to short Make sure that there is enough liquidity in each of those stocks to execute trades, Identify stocks that has a Total_OI of greater than 5000 as liquid stocks. We will assign them ranks ordered by premium based on their liquidity status.
# ### SQL Feautres USED:
# ### CTE, CASE, JOIN, Window Function

# %%
# %%sql
# WITH stock_premium AS (
# SELECT ns.Stock_Ticker,
# 	sp.Prices,
# 	Call_price,
# 	put_price,
# 	Call_price + put_price AS Straddle_Price,
# 	ROUND(((Call_price + put_price)/Prices)*100,2) AS Premium,
# 	CASE WHEN sp.Prices >= 3000 THEN "High Value Stock" ELSE "Low Value Stock" END AS Stock_Type
# FROM Non_Zero_Stock ns
# JOIN Stock_Prices sp
# 	ON ns.Stock_Ticker = sp.Stock_Ticker
# ORDER BY ROUND(((Call_price + put_price)/Prices)*100,2) DESC
# ),
# liquidity_status AS (
# SELECT
# 	STOCK,
# 	Premium,
# 	CE_OI + PE_OI AS Total_OI,
# 	CASE WHEN CE_OI + PE_OI > 5000 THEN "Liquid" ELSE "Not Liquid" END AS Liquidity_Status
# FROM CALL_PUT_OI cpo
# JOIN stock_premium sp1
# ON cpo.STOCK = sp1.Stock_Ticker
# ORDER BY Premium DESC
# )
# SELECT
# 	RANK () OVER (PARTITION BY liquidity_status
# 	ORDER BY Premium DESC) AS Premium_Rank,
# 	STOCK,
# 	Premium,
# 	Total_OI,
# 	Liquidity_Status
# FROM liquidity_status
# ORDER BY liquidity_status, Premium_Rank
# Out:
#  * mysql://admin:***@project-db.c8h2tkspsqfa.us-east-1.rds.amazonaws.com/Stock_Prices
# 160 rows affected.
# [(1, 'IDEA', 14.85, 5316, 'Liquid'),
#  (2, 'IBULHSGFIN', 13.18, 7010, 'Liquid'),
#  (3, 'MOTHERSUMI', 11.8, 6270, 'Liquid'),
#  (4, 'ZEEL', 11.19, 20515, 'Liquid'),
#  (5, 'ESCORTS', 10.59, 7194, 'Liquid'),
#  (6, 'BSOFT', 10.46, 6575, 'Liquid'),
#  (7, 'JUBLFOOD', 10.27, 16826, 'Liquid'),
#  (8, 'BHEL', 10.13, 8639, 'Liquid'),
#  (9, 'JINDALSTEL', 9.94, 5683, 'Liquid'),
#  (10, 'RBLBANK', 9.86, 9216, 'Liquid'),
#  (11, 'IDFCFIRSTB', 9.7, 15753, 'Liquid'),
#  (12, 'MANAPPURAM', 9.69, 7473, 'Liquid'),
#  (13, 'NATIONALUM', 9.62, 5083, 'Liquid'),
#  (14, 'MINDTREE', 9.51, 5642, 'Liquid'),
#  (15, 'APOLLOHOSP', 9.5, 9971, 'Liquid'),
#  (16, 'BANDHANBNK', 9.47, 8087, 'Liquid'),
#  (17, 'DEEPAKNTR', 9.44, 5970, 'Liquid'),
#  (18, 'ASHOKLEY', 9.34, 5986, 'Liquid'),
#  (19, 'TATAMOTORS', 9.33, 36057, 'Liquid'),
#  (20, 'GODREJPROP', 9.3, 5918, 'Liquid'),
#  (21, 'DIXON', 9.28, 5907, 'Liquid'),
#  (22, 'IEX', 9.21, 11532, 'Liquid'),
#  (23, 'INDHOTEL', 9.16, 5425, 'Liquid'),
#  (24, 'IDFC', 9.11, 6045, 'Liquid'),
#  (25, 'DLF', 9.09, 9308, 'Liquid'),
#  (26, 'BANKBARODA', 9.05, 6983, 'Liquid'),
#  (27, 'HINDALCO', 9.04, 25593, 'Liquid'),
#  (28, 'IRCTC', 8.98, 12404, 'Liquid'),
#  (28, 'TATASTEEL', 8.98, 41104, 'Liquid'),
#  (30, 'ADANIENT', 8.92, 18100, 'Liquid'),
#  (31, 'CONCOR', 8.85, 5584, 'Liquid'),
#  (32, 'ADANIPORTS', 8.82, 18203, 'Liquid'),
#  (33, 'SRF', 8.74, 7593, 'Liquid'),
#  (34, 'VEDL', 8.73, 8074, 'Liquid'),
#  (35, 'TATAPOWER', 8.62, 24101, 'Liquid'),
#  (36, 'LICHSGFIN', 8.58, 6725, 'Liquid'),
#  (37, 'JSWSTEEL', 8.51, 8104, 'Liquid'),
#  (38, 'AUROPHARMA', 8.32, 8634, 'Liquid'),
#  (39, 'AMBUJACEM', 8.2, 6315, 'Liquid'),
#  (40, 'BEL', 8.19, 9925, 'Liquid'),
#  (40, 'PEL', 8.19, 5430, 'Liquid'),
#  (42, 'COALINDIA', 8.09, 13383, 'Liquid'),
#  (43, 'TATACHEM', 8.04, 5570, 'Liquid'),
#  (44, 'HEROMOTOCO', 8.03, 13419, 'Liquid'),
#  (45, 'GODREJCP', 7.99, 5418, 'Liquid'),
#  (46, 'FEDERALBNK', 7.85, 7280, 'Liquid'),
#  (47, 'PNB', 7.7, 10675, 'Liquid'),
#  (48, 'BAJAJFINSV', 7.67, 12829, 'Liquid'),
#  (49, 'VOLTAS', 7.58, 12497, 'Liquid'),
#  (50, 'HAVELLS', 7.54, 6903, 'Liquid'),
#  (51, 'NMDC', 7.52, 7414, 'Liquid'),
#  (52, 'TATACONSUM', 7.45, 8439, 'Liquid'),
#  (53, 'INDUSINDBK', 7.32, 12675, 'Liquid'),
#  (54, 'ONGC', 7.3, 8547, 'Liquid'),
#  (55, 'MARUTI', 7.11, 22886, 'Liquid'),
#  (56, 'BAJFINANCE', 7.03, 27387, 'Liquid'),
#  (57, 'SBICARD', 7.02, 8314, 'Liquid'),
#  (58, 'TECHM', 6.92, 12388, 'Liquid'),
#  (59, 'LUPIN', 6.73, 7802, 'Liquid'),
#  (60, 'DIVISLAB', 6.71, 6529, 'Liquid'),
#  (61, 'AXISBANK', 6.65, 20885, 'Liquid'),
#  (62, 'TITAN', 6.59, 21308, 'Liquid'),
#  (63, 'UPL', 6.55, 6907, 'Liquid'),
#  (64, 'HDFCLIFE', 6.47, 12697, 'Liquid'),
#  (65, 'SBIN', 6.45, 39700, 'Liquid'),
#  (66, 'DRREDDY', 6.42, 12784, 'Liquid'),
#  (67, 'CIPLA', 6.41, 12867, 'Liquid'),
#  (68, 'ULTRACEMCO', 6.36, 7774, 'Liquid'),
#  (68, 'IOC', 6.36, 6127, 'Liquid'),
#  (70, 'WIPRO', 6.31, 35784, 'Liquid'),
#  (71, 'ASIANPAINT', 6.28, 14306, 'Liquid'),
#  (72, 'INFY', 6.06, 57620, 'Liquid'),
#  (73, 'ICICIBANK', 6.05, 32924, 'Liquid'),
#  (73, 'KOTAKBANK', 6.05, 25884, 'Liquid'),
#  (75, 'BPCL', 6.02, 8078, 'Liquid'),
#  (76, 'HCLTECH', 5.93, 18406, 'Liquid'),
#  (77, 'ITC', 5.69, 48367, 'Liquid'),
#  (78, 'PFC', 5.63, 5824, 'Liquid'),
#  (79, 'RELIANCE', 5.56, 84354, 'Liquid'),
#  (80, 'BHARTIARTL', 5.39, 29062, 'Liquid'),
#  (81, 'NTPC', 5.36, 22536, 'Liquid'),
#  (82, 'TCS', 5.3, 60580, 'Liquid'),
#  (83, 'SUNPHARMA', 5.29, 14339, 'Liquid'),
#  (84, 'POWERGRID', 5.23, 8508, 'Liquid'),
#  (85, 'HDFCBANK', 5.09, 91478, 'Liquid'),
#  (86, 'BANKNIFTY', 5.06, 2214774, 'Liquid'),
#  (87, 'HDFC', 5.05, 54339, 'Liquid'),
#  (88, 'LT', 5.04, 12693, 'Liquid'),
#  (89, 'HINDUNILVR', 4.9, 16804, 'Liquid'),
#  (90, 'NIFTY', 3.74, 2345944, 'Liquid'),
#  (1, 'BALRAMCHIN', 11.38, 4435, 'Not Liquid'),
#  (2, 'DELTACORP', 11.3, 4344, 'Not Liquid'),
#  (3, 'STAR', 11.26, 2603, 'Not Liquid'),
#  (4, 'FSL', 10.99, 4096, 'Not Liquid'),
#  (5, 'INDIAMART', 10.75, 4476, 'Not Liquid'),
#  (6, 'RAIN', 10.54, 1657, 'Not Liquid'),
#  (7, 'CHAMBLFERT', 10.33, 2594, 'Not Liquid'),
#  (8, 'METROPOLIS', 10.28, 2662, 'Not Liquid'),
#  (8, 'INTELLECT', 10.28, 883, 'Not Liquid'),
#  (8, 'GNFC', 10.28, 4715, 'Not Liquid'),
#  (11, 'GSPL', 10.08, 927, 'Not Liquid'),
#  (12, 'INDUSTOWER', 9.98, 4669, 'Not Liquid'),
#  (13, 'GUJGASLTD', 9.97, 3840, 'Not Liquid'),
#  (14, 'NBCC', 9.95, 1036, 'Not Liquid'),
#  (15, 'OBEROIRLTY', 9.6, 1574, 'Not Liquid'),
#  (15, 'ABFRL', 9.6, 3360, 'Not Liquid'),
#  (17, 'INDIGO', 9.45, 4946, 'Not Liquid'),
#  (18, 'LALPATHLAB', 9.44, 1930, 'Not Liquid'),
#  (18, 'SRTRANSFIN', 9.44, 3323, 'Not Liquid'),
#  (20, 'GMRINFRA', 9.29, 3260, 'Not Liquid'),
#  (21, 'PVR', 9.28, 4761, 'Not Liquid'),
#  (22, 'LTI', 9.18, 2610, 'Not Liquid'),
#  (22, 'COFORGE', 9.18, 4989, 'Not Liquid'),
#  (24, 'NAUKRI', 9.16, 4982, 'Not Liquid'),
#  (25, 'HAL', 9.1, 4138, 'Not Liquid'),
#  (26, 'LTTS', 9.07, 2479, 'Not Liquid'),
#  (27, 'WHIRLPOOL', 8.91, 2371, 'Not Liquid'),
#  (28, 'TATACOMM', 8.88, 4622, 'Not Liquid'),
#  (28, 'PERSISTENT', 8.88, 756, 'Not Liquid'),
#  (30, 'APOLLOTYRE', 8.81, 3634, 'Not Liquid'),
#  (31, 'AUBANK', 8.77, 2715, 'Not Liquid'),
#  (32, 'SYNGENE', 8.68, 416, 'Not Liquid'),
#  (33, 'CUMMINSIND', 8.43, 1092, 'Not Liquid'),
#  (34, 'NAM-INDIA', 8.41, 843, 'Not Liquid'),
#  (35, 'BALKRISIND', 8.33, 1979, 'Not Liquid'),
#  (36, 'TORNTPOWER', 8.3, 1423, 'Not Liquid'),
#  (37, 'TRENT', 8.22, 2067, 'Not Liquid'),
#  (38, 'HINDPETRO', 8.2, 2797, 'Not Liquid'),
#  (39, 'GLENMARK', 8.15, 2067, 'Not Liquid'),
#  (39, 'LAURUSLABS', 8.15, 2224, 'Not Liquid'),
#  (41, 'MGL', 8.11, 3179, 'Not Liquid'),
#  (42, 'CHOLAFIN', 8.05, 2713, 'Not Liquid'),
#  (43, 'AARTIIND', 8.02, 1305, 'Not Liquid'),
#  (44, 'CANBK', 8.0, 4855, 'Not Liquid'),
#  (45, 'BHARATFORG', 7.97, 2272, 'Not Liquid'),
#  (46, 'UBL', 7.88, 1047, 'Not Liquid'),
#  (47, 'GRANULES', 7.75, 1403, 'Not Liquid'),
#  (48, 'MCX', 7.74, 3620, 'Not Liquid'),
#  (49, 'IGL', 7.7, 4536, 'Not Liquid'),
#  (50, 'BERGEPAINT', 7.56, 802, 'Not Liquid'),
#  (51, 'NAVINFLUOR', 7.55, 800, 'Not Liquid'),
#  (52, 'SUNTV', 7.53, 1267, 'Not Liquid'),
#  (53, 'ACC', 7.52, 4779, 'Not Liquid'),
#  (54, 'TVSMOTOR', 7.48, 2697, 'Not Liquid'),
#  (55, 'CUB', 7.36, 1085, 'Not Liquid'),
#  (56, 'MUTHOOTFIN', 7.33, 3344, 'Not Liquid'),
#  (57, 'BATAINDIA', 7.22, 1808, 'Not Liquid'),
#  (58, 'BIOCON', 7.18, 4774, 'Not Liquid'),
#  (59, 'OFSS', 7.14, 724, 'Not Liquid'),
#  (60, 'PAGEIND', 7.02, 172, 'Not Liquid'),
#  (61, 'COROMANDEL', 6.94, 1002, 'Not Liquid'),
#  (62, 'ALKEM', 6.88, 617, 'Not Liquid'),
#  (63, 'SBILIFE', 6.76, 2422, 'Not Liquid'),
#  (64, 'BOSCHLTD', 6.72, 763, 'Not Liquid'),
#  (65, 'GRASIM', 6.7, 2297, 'Not Liquid'),
#  (66, 'MCDOWELL-N', 6.53, 4165, 'Not Liquid'),
#  (67, 'RECLTD', 6.14, 4428, 'Not Liquid'),
#  (68, 'ABBOTINDIA', 5.98, 740, 'Not Liquid'),
#  (69, 'MARICO', 5.82, 3743, 'Not Liquid'),
#  (70, 'COLPAL', 5.23, 1811, 'Not Liquid')]

# %% [markdown]
# #### As it can be seen from the data now we can identify the highest stock premiums in liquid and non liquid categories.

# %% [markdown]
# ## Additional Question 2 : Calculate the Skew between the call and Put prices, High skew percentage in a stock indicates that there is a discreptancy with the option pricing model and traders can go in there and use arbitrage techniques to earn a profit.
# ### Sql feautres Used: JOIN

# %%
# %%sql
# SELECT ap.Stock_Ticker,
# 	Prices,
# 	ATM_Strike,
# 	Call_price,
# 	put_price,
# 	ROUND(((ABS(ABS(Call_price-put_price)-ABS(Prices - ATM_Strike)))/LEAST(Call_price,put_price))*100,2) AS skew
# FROM ATM_prices ap
# JOIN Stock_Prices sp
# 	ON ap.Stock_Ticker = sp.Stock_Ticker
# WHERE ap.Stock_Ticker IN (
# 	SELECT STOCK
# 	FROM CALL_PUT_OI cpo
# 	WHERE CE_OI + PE_OI > 5000)
# AND Call_price > 0 AND put_price > 0
# ORDER BY ROUND(((ABS(ABS(Call_price-put_price)-ABS(Prices - ATM_Strike)))/LEAST(Call_price,put_price))*100,2) DESC
# Out:
#  * mysql://admin:***@project-db.c8h2tkspsqfa.us-east-1.rds.amazonaws.com/Stock_Prices
# 90 rows affected.
# [('ESCORTS', 1700.0, 1700.0, 18.0, 162.0, 800.0),
#  ('LT', 1786.2, 1780.0, 53.7, 36.3, 30.85),
#  ('NIFTY', 17670.45, 17650.0, 375.85, 285.0, 24.7),
#  ('LUPIN', 763.45, 760.0, 30.0, 21.4, 24.07),
#  ('PNB', 36.35, 36.0, 1.7, 1.1, 22.73),
#  ('ITC', 255.05, 255.0, 8.0, 6.5, 22.31),
#  ('BAJFINANCE', 7429.0, 7400.0, 299.0, 223.55, 20.78),
#  ('HINDUNILVR', 2082.6, 2080.0, 56.75, 45.25, 19.67),
#  ('PFC', 116.4, 116.0, 3.75, 2.8, 19.64),
#  ('INDHOTEL', 241.3, 240.0, 12.6, 9.5, 18.95),
#  ('TECHM', 1489.0, 1480.0, 60.0, 43.0, 18.6),
#  ('LICHSGFIN', 372.35, 370.0, 18.35, 13.6, 17.65),
#  ('SUNPHARMA', 911.8, 910.0, 26.85, 21.35, 17.33),
#  ('HDFC', 2462.25, 2460.0, 68.0, 56.35, 16.68),
#  ('KOTAKBANK', 1780.0, 1780.0, 58.0, 49.75, 16.58),
#  ('WIPRO', 602.75, 605.0, 16.55, 21.5, 16.31),
#  ('NMDC', 166.3, 167.5, 6.15, 6.35, 16.26),
#  ('TITAN', 2526.0, 2520.0, 92.2, 74.2, 16.17),
#  ('COALINDIA', 186.0, 185.0, 8.55, 6.5, 16.15),
#  ('VEDL', 405.9, 405.0, 19.45, 16.0, 15.94),
#  ('TATAPOWER', 245.8, 245.0, 11.75, 9.45, 15.87),
#  ('DIVISLAB', 4375.0, 4350.0, 169.2, 124.55, 15.78),
#  ('HDFCBANK', 1507.5, 1510.0, 34.4, 42.3, 15.7),
#  ('MANAPPURAM', 120.7, 120.0, 6.6, 5.1, 15.69),
#  ('FEDERALBNK', 101.3, 101.0, 4.4, 3.55, 15.49),
#  ('IDEA', 10.1, 10.0, 0.85, 0.65, 15.38),
#  ('BANKNIFTY', 37148.5, 37100.0, 1028.0, 850.1, 15.22),
#  ('BEL', 214.8, 215.0, 9.5, 8.1, 14.81),
#  ('IEX', 230.85, 230.0, 11.75, 9.5, 14.74),
#  ('DLF', 385.0, 385.0, 18.7, 16.3, 14.72),
#  ('JINDALSTEL', 530.35, 530.0, 28.3, 24.4, 14.55),
#  ('BAJAJFINSV', 17150.0, 17250.0, 660.0, 655.0, 14.5),
#  ('ADANIPORTS', 783.5, 780.0, 38.5, 30.6, 14.38),
#  ('ULTRACEMCO', 6656.05, 6700.0, 204.0, 219.0, 14.19),
#  ('IBULHSGFIN', 167.35, 165.0, 12.85, 9.2, 14.13),
#  ('TATAMOTORS', 440.9, 440.0, 22.35, 18.8, 14.1),
#  ('JUBLFOOD', 2726.0, 2750.0, 137.55, 142.3, 13.99),
#  ('IOC', 121.95, 122.0, 4.15, 3.6, 13.89),
#  ('ADANIENT', 2038.0, 2040.0, 97.5, 84.35, 13.22),
#  ('RELIANCE', 2661.0, 2660.0, 79.0, 69.0, 13.04),
#  ('DRREDDY', 4278.0, 4300.0, 134.95, 139.5, 12.93),
#  ('HEROMOTOCO', 2246.0, 2240.0, 98.3, 82.0, 12.56),
#  ('AUROPHARMA', 682.5, 680.0, 31.2, 25.55, 12.33),
#  ('MINDTREE', 4243.3, 4200.0, 233.25, 170.15, 11.64),
#  ('CONCOR', 681.0, 680.0, 32.2, 28.05, 11.23),
#  ('PEL', 2232.7, 2250.0, 87.5, 95.3, 10.86),
#  ('DEEPAKNTR', 2300.0, 2300.0, 114.05, 103.0, 10.73),
#  ('BANKBARODA', 116.0, 116.0, 5.5, 5.0, 10.0),
#  ('SBICARD', 870.0, 870.0, 32.0, 29.1, 9.97),
#  ('TCS', 3759.0, 3760.0, 104.8, 94.4, 9.96),
#  ('ONGC', 167.7, 167.5, 6.5, 5.75, 9.57),
#  ('UPL', 781.55, 780.0, 27.45, 23.75, 9.05),
#  ('BANDHANBNK', 320.1, 320.0, 15.85, 14.45, 9.0),
#  ('AXISBANK', 773.5, 770.0, 28.5, 22.95, 8.93),
#  ('HAVELLS', 1172.5, 1180.0, 42.3, 46.05, 8.87),
#  ('IDFC', 63.65, 64.0, 2.95, 2.85, 8.77),
#  ('MARUTI', 7670.0, 7700.0, 269.05, 276.45, 8.4),
#  ('AMBUJACEM', 305.0, 305.0, 13.0, 12.0, 8.33),
#  ('SRF', 2625.8, 2620.0, 122.0, 107.55, 8.04),
#  ('MOTHERSUMI', 140.25, 140.0, 8.7, 7.85, 7.64),
#  ('ICICIBANK', 736.0, 740.0, 21.05, 23.45, 7.6),
#  ('HDFCLIFE', 551.1, 550.0, 19.0, 16.65, 7.51),
#  ('JSWSTEEL', 732.45, 730.0, 33.45, 28.85, 7.45),
#  ('ZEEL', 299.45, 300.0, 17.6, 15.9, 7.23),
#  ('HINDALCO', 571.0, 570.0, 27.15, 24.45, 6.95),
#  ('VOLTAS', 1260.0, 1260.0, 49.3, 46.15, 6.83),
#  ('APOLLOHOSP', 4501.5, 4500.0, 221.5, 206.0, 6.8),
#  ('RBLBANK', 136.95, 137.5, 6.8, 6.7, 6.72),
#  ('SBIN', 508.0, 510.0, 16.85, 15.9, 6.6),
#  ('POWERGRID', 225.45, 225.0, 6.3, 5.5, 6.36),
#  ('ASHOKLEY', 119.35, 120.0, 5.4, 5.75, 5.56),
#  ('IDFCFIRSTB', 41.75, 42.0, 1.95, 2.1, 5.13),
#  ('INFY', 1906.8, 1900.0, 62.5, 53.0, 5.09),
#  ('BPCL', 374.65, 375.0, 11.7, 10.85, 4.61),
#  ('NTPC', 142.8, 143.0, 4.0, 3.65, 4.11),
#  ('GODREJCP', 754.25, 750.0, 32.8, 27.5, 3.82),
#  ('BSOFT', 468.4, 470.0, 24.1, 24.9, 3.32),
#  ('TATASTEEL', 1317.15, 1320.0, 59.95, 58.3, 2.06),
#  ('BHEL', 53.8, 54.0, 2.8, 2.65, 1.89),
#  ('NATIONALUM', 122.15, 122.5, 6.0, 5.75, 1.74),
#  ('BHARTIARTL', 758.35, 760.0, 19.7, 21.15, 1.02),
#  ('ASIANPAINT', 3112.2, 3120.0, 102.0, 93.35, 0.91),
#  ('GODREJPROP', 1694.25, 1700.0, 81.4, 76.2, 0.72),
#  ('IRCTC', 797.75, 800.0, 34.8, 36.8, 0.72),
#  ('TATACONSUM', 788.25, 790.0, 30.3, 28.4, 0.53),
#  ('INDUSINDBK', 968.0, 970.0, 36.4, 34.5, 0.29),
#  ('TATACHEM', 985.85, 990.0, 41.75, 37.5, 0.27),
#  ('HCLTECH', 1173.2, 1170.0, 36.35, 33.2, 0.15),
#  ('DIXON', 4365.15, 4400.0, 185.0, 219.95, 0.05),
#  ('CIPLA', 1018.65, 1020.0, 33.3, 31.95, 0.0)]

# %% [markdown]
# #### Our data reveals that several of our stocks have high skews with ESCORTS having 800 percent skew,

# %% [markdown]
# ### In this query we will be analyzing the option premium according to their liquidity status and stock valuation, illiquid stocks with low valuations tend to have a higher valuation.
# ### sql features used: CASE, CTE, JOIN, Aggregate Funtions

# %%
# %%sql
# WITH Value_Sort AS
# 	(SELECT ns.Stock_Ticker,
# 	sp.Prices,
# 	Call_price,
# 	put_price,
# 	Call_price + put_price AS Straddle_Price,
# 	ROUND(((Call_price + put_price)/Prices)*100,2) AS Premium,
# 	CASE WHEN sp.Prices >= 3000 THEN "High Value Stock" ELSE "Low Value Stock" END AS Stock_Type
# FROM Non_Zero_Stock ns
# JOIN Stock_Prices sp
# 	ON ns.Stock_Ticker = sp.Stock_Ticker
# ORDER BY ROUND(((Call_price + put_price)/Prices)*100,2) DESC
# ),
# status_of_liquidity AS (
# 	SELECT STOCK,
# 		CE_OI + PE_OI AS Total_OI,
# 		CASE WHEN (CE_OI + PE_OI) > 5000 THEN "Liquid" ELSE "Non-Liquid" END AS Liquidity_Status
# 	FROM CALL_PUT_OI cpo
# )
# SELECT
# 	Stock_Type,
# 	Liquidity_Status,
# 	ROUND(AVG(premium),2) AS Average_Premium
# FROM status_of_liquidity sl
# JOIN Value_Sort vs
# 	ON sl.STOCK = vs.Stock_Ticker
# GROUP BY Stock_Type, Liquidity_Status ;
# Out:
#  * mysql://admin:***@project-db.c8h2tkspsqfa.us-east-1.rds.amazonaws.com/Stock_Prices
# 4 rows affected.
# [('High Value Stock', 'Liquid', 6.92),
#  ('Low Value Stock', 'Liquid', 8.01),
#  ('Low Value Stock', 'Non-Liquid', 8.56),
#  ('High Value Stock', 'Non-Liquid', 8.13)]

# %% [markdown]
# ### as suspecetd illiquid stocks with low value have the highest premium
